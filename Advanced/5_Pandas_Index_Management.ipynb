# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset(
    'lukebarousse/data_jobs',
    split='train'
)

# Convert to Pandas
df = dataset.to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

print("Data loaded successfully!")
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from datasets import load_dataset
#       4
#       5 # Loading Data
#       6 dataset = load_dataset(
#
# ModuleNotFoundError: No module named 'datasets'

# %%
# %pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-5.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: filelock in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (3.29.4)
# Requirement already satisfied: numpy>=1.17 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (2.4.6)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (4.68.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-4.0.1-cp314-cp314-win_amd64.whl.metadata (18 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Downloading multiprocess-0.70.19-py314-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2026.6.0,>=2023.1.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (2026.4.0)
# Collecting huggingface-hub<2.0,>=0.25.0 (from datasets)
#   Downloading huggingface_hub-1.30.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in c:\Users\LENOVO\anaconda3\Lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in c:\Users\LENOVO\anaconda3\Lib\site-packages (from httpx<1.0.0->datasets) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\LENOVO\anaconda3\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\Users\LENOVO\anaconda3\Lib\site-packages (from httpx<1.0.0->datasets) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: colorama in c:\Users\LENOVO\anaconda3\Lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\LENOVO\anaconda3\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\LENOVO\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-5.0.1-py3-none-any.whl (559 kB)
#    ---------------------------------------- 0.0/559.1 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/559.1 kB ? eta -:--:--
#    ---------------------------------------- 559.1/559.1 kB 1.7 MB/s  0:00:00
# Downloading huggingface_hub-1.30.0-py3-none-any.whl (796 kB)
#    ---------------------------------------- 0.0/796.8 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/796.8 kB ? eta -:--:--
#    ---------------------------------------- 796.8/796.8 kB 2.0 MB/s  0:00:00
# Downloading click-8.5.0-py3-none-any.whl (125 kB)
# Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 2.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.8/4.0 MB 2.1 MB/s eta 0:00:02
#    --------------- ------------------------ 1.6/4.0 MB 2.2 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 2.3 MB/s eta 0:00:01
#    -------------------- ------------------- 2.1/4.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 1.8 MB/s  0:00:02
# Downloading multiprocess-0.70.19-py314-none-any.whl (160 kB)
# Downloading xxhash-4.0.1-cp314-cp314-win_amd64.whl (37 kB)
# Installing collected packages: xxhash, multiprocess, hf-xet, click, huggingface-hub, datasets
#
#    ------ --------------------------------- 1/6 [multiprocess]
#    ------ --------------------------------- 1/6 [multiprocess]
#    ------ --------------------------------- 1/6 [multiprocess]
#    ------------- -------------------------- 2/6 [hf-xet]
#   Attempting uninstall: click
#    ------------- -------------------------- 2/6 [hf-xet]
#     Found existing installation: click 8.4.1
#    ------------- -------------------------- 2/6 [hf-xet]
#    -------------------- ------------------- 3/6 [click]
#     Uninstalling click-8.4.1:
#    -------------------- ------------------- 3/6 [click]
#       Successfully uninstalled click-8.4.1
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    -------------------------- ------------- 4/6 [huggingface-hub]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    --------------------------------- ------ 5/6 [datasets]
#    ---------------------------------------- 6/6 [datasets]
#
# Successfully installed click-8.5.0 datasets-5.0.1 hf-xet-1.6.0 huggingface-hub-1.30.0 multiprocess-0.70.19 xxhash-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset(
    'lukebarousse/data_jobs',
    split='train'
)

# Convert to Pandas
df = dataset.to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

print("Data loaded successfully!")
print(df.shape)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Data loaded successfully!
# (785741, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.sample(5)
# Out:
#              job_title_short                              job_title  \
# 686029          Data Analyst                         Data Analytics
# 150520          Data Analyst  Credit Risk Data Analyst - Now Hiring
# 782292  Senior Data Engineer                   Senior Data Engineer
# 400371        Data Scientist                      Data Scientist II
# 779388     Software Engineer          Software Development Engineer
#
#                  job_location                job_via job_schedule_type  \
# 686029         Poznań, Poland  via Praca Trabajo.org         Full-time
# 150520              Tampa, FL           via Snagajob         Full-time
# 782292               Anywhere       via ZipRecruiter         Full-time
# 400371             Dallas, TX              via BeBee         Full-time
# 779388  Schiphol, Netherlands              via BeBee         Temp work
#
#         job_work_from_home          search_location     job_posted_date  \
# 686029               False                   Poland 2023-12-26 10:09:44
# 150520               False   Florida, United States 2023-01-29 08:02:36
# 782292                True  New York, United States 2023-09-28 06:05:37
# 400371               False                    Sudan 2023-02-28 18:36:19
# 779388               False              Netherlands 2023-09-30 05:19:50
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 686029                   True                 False         Poland
# 150520                   True                 False  United States
# 782292                   True                 False  United States
# 400371                  False                 False          Sudan
# 779388                  False                 False    Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg    company_name  \
# 686029         NaN              NaN              NaN             GSK
# 150520         NaN              NaN              NaN  Selby Jennings
# 782292         NaN              NaN              NaN          gWorks
# 400371         NaN              NaN              NaN           Chewy
# 779388         NaN              NaN              NaN             KLM
#
#                                                job_skills  \
# 686029                       ['sql', 'azure', 'power bi']
# 150520               ['sas', 'sas', 'sql', 'r', 'python']
# 782292  ['sql', 't-sql', 'postgresql', 'sql server', '...
# 400371  ['python', 'sql', 'r', 'sas', 'sas', 'scala', ...
# 779388                                            ['c++']
#
#                                           job_type_skills
# 686029  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 150520  {'analyst_tools': ['sas'], 'programming': ['sa...
# 782292  {'cloud': ['aws', 'aurora', 'azure'], 'databas...
# 400371  {'analyst_tools': ['sas'], 'cloud': ['aws', 'r...
# 779388                           {'programming': ['c++']}

# %%
df.index.name = 'job_index'

# %%
df
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# 785737                                      CRM Data Analyst
# 785738                        Commercial Analyst - Start Now
# 785739     Principal Associate, Data Engineer (Remote-Eli...
# 785740                                    AWS System Analyst
#
#                                   job_location                    job_via  \
# job_index
# 0                                Watertown, CT            via Work Nearby
# 1                 Guadalajara, Jalisco, Mexico           via BeBee México
# 2                              Berlin, Germany               via LinkedIn
# 3                              San Antonio, TX          via Diversity.com
# 4                               Washington, DC         via Clearance Jobs
# ...                                        ...                        ...
# 785736                               Singapura        melalui Trabajo.org
# 785737                      Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                                Malaysia           melalui Ricebowl
# 785739     Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                   India             melalui Trigyn
#
#           job_schedule_type  job_work_from_home       search_location  \
# job_index
# 0                 Full-time               False  Texas, United States
# 1                 Full-time               False                Mexico
# 2                 Full-time               False               Germany
# 3                 Full-time               False  Texas, United States
# 4                 Full-time               False                 Sudan
# ...                     ...                 ...                   ...
# 785736      Pekerjaan tetap               False             Singapore
# 785737      Pekerjaan tetap               False               Germany
# 785738      Pekerjaan tetap               False              Malaysia
# 785739      Pekerjaan tetap               False                 Sudan
# 785740      Pekerjaan tetap               False                 India
#
#               job_posted_date  job_no_degree_mention  job_health_insurance  \
# job_index
# 0         2023-06-16 13:44:15                  False                 False
# 1         2023-01-14 13:18:07                  False                 False
# 2         2023-10-10 13:14:55                  False                 False
# 3         2023-07-04 13:01:41                   True                 False
# 4         2023-08-07 14:29:36                  False                 False
# ...                       ...                    ...                   ...
# 785736    2023-03-13 06:16:16                  False                 False
# 785737    2023-03-12 06:18:18                  False                 False
# 785738    2023-03-12 06:32:36                  False                 False
# 785739    2023-03-12 06:32:15                  False                 False
# 785740    2023-03-13 06:16:31                  False                 False
#
#              job_country salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0          United States         NaN              NaN              NaN
# 1                 Mexico         NaN              NaN              NaN
# 2                Germany         NaN              NaN              NaN
# 3          United States         NaN              NaN              NaN
# 4                  Sudan         NaN              NaN              NaN
# ...                  ...         ...              ...              ...
# 785736         Singapore         NaN              NaN              NaN
# 785737           Germany         NaN              NaN              NaN
# 785738          Malaysia         NaN              NaN              NaN
# 785739             Sudan         NaN              NaN              NaN
# 785740             India         NaN              NaN              NaN
#
#                                  company_name  \
# job_index
# 0                        Boehringer Ingelheim
# 1                  Hewlett Packard Enterprise
# 2                    ALPHA Augmented Services
# 3                Southwest Research Institute
# 4                             Kristina Daniel
# ...                                       ...
# 785736     CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                       HABA FAMILYGROUP
# 785738                  Lendlease Corporation
# 785739                            Capital One
# 785740                                 Trigyn
#
#                                                   job_skills  \
# job_index
# 0                                                        NaN
# 1          ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2          ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4          ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                      ...
# 785736     ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                        ['sas', 'sas', 'sql', 'excel']
# 785738                               ['powerpoint', 'excel']
# 785739     ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                       ['aws', 'flow']
#
#                                              job_type_skills
# job_index
# 0                                                        NaN
# 1          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4          {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                      ...
# 785736     {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737     {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738            {'analyst_tools': ['powerpoint', 'excel']}
# 785739     {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740                 {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country'] == 'United States']

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 5                 NaN              NaN              NaN
# 6                 NaN              NaN              NaN
# 9                 NaN              NaN              NaN
# ...               ...              ...              ...
# 785673            NaN              NaN              NaN
# 785685            NaN              NaN              NaN
# 785692           year         157500.0              NaN
# 785703            NaN              NaN              NaN
# 785705            NaN              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                        NaN
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                   NaN
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                   NaN
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                        NaN
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                   NaN
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                   NaN
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
df_usa.reset_index(inplace = True)
df_usa
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# 206287                    Asset Management Data Scientist      New York, NY
# 206288                                       Data Analyst  Indianapolis, IN
# 206289               Data Scientist- Hybrid Work Location        Dayton, OH
# 206290            Data Analyst - CRYPTOGRAPHY - Full-time          Anywhere
# 206291          Expert Business Data Analyst - Now Hiring       Oakland, CA
#
#                   job_via         job_schedule_type  job_work_from_home  \
# 0         via Work Nearby                 Full-time               False
# 1       via Diversity.com                 Full-time               False
# 2        via ZipRecruiter  Contractor and Temp work                True
# 3            via LinkedIn                 Full-time               False
# 4        via ZipRecruiter                 Full-time                True
# ...                   ...                       ...                 ...
# 206287    via Trabajo.org                 Full-time               False
# 206288    via Trabajo.org                 Full-time               False
# 206289    via Ai-Jobs.net                 Full-time               False
# 206290       via Snagajob                 Full-time                True
# 206291       via Snagajob                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 0            Texas, United States 2023-06-16 13:44:15                  False
# 1            Texas, United States 2023-07-04 13:01:41                   True
# 2                         Georgia 2023-11-07 14:01:59                  False
# 3          Florida, United States 2023-03-27 13:18:18                  False
# 4         New York, United States 2023-04-23 13:02:57                  False
# ...                           ...                 ...                    ...
# 206287    New York, United States 2023-10-16 06:01:53                   True
# 206288    Illinois, United States 2023-07-16 06:01:27                   True
# 206289    Illinois, United States 2023-04-21 06:02:31                  False
# 206290       Texas, United States 2023-01-28 06:02:55                   True
# 206291  California, United States 2023-01-09 06:00:25                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States         NaN              NaN
# 1                      False  United States         NaN              NaN
# 2                      False  United States         NaN              NaN
# 3                      False  United States         NaN              NaN
# 4                      False  United States         NaN              NaN
# ...                      ...            ...         ...              ...
# 206287                 False  United States         NaN              NaN
# 206288                 False  United States         NaN              NaN
# 206289                  True  United States        year         157500.0
# 206290                 False  United States         NaN              NaN
# 206291                 False  United States         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 0                   NaN           Boehringer Ingelheim
# 1                   NaN   Southwest Research Institute
# 2                   NaN                smart folks inc
# 3                   NaN  Miracle Software Systems, Inc
# 4                   NaN     Radwell International, LLC
# ...                 ...                            ...
# 206287              NaN           JPMorgan Chase & Co.
# 206288              NaN         Aara Technologies, Inc
# 206289              NaN                         Tenet3
# 206290              NaN    Axelon Services Corporation
# 206291              NaN               PG&E Corporation
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                                ['python', 'sql', 'gcp']
# 3       ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                   ...
# 206287                                                NaN
# 206288                                   ['sql', 'excel']
# 206289                          ['python', 'matlab', 'r']
# 206290                                                NaN
# 206291                       ['sql', 'python', 'tableau']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2       {'cloud': ['gcp'], 'programming': ['python', '...
# 3       {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                   ...
# 206287                                                NaN
# 206288  {'analyst_tools': ['excel'], 'programming': ['...
# 206289         {'programming': ['python', 'matlab', 'r']}
# 206290                                                NaN
# 206291  {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 18 columns]

# %%
df_usa.set_index('job_index', inplace = True)

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# 785685                                          Data Analyst
# 785692                  Data Scientist- Hybrid Work Location
# 785703               Data Analyst - CRYPTOGRAPHY - Full-time
# 785705             Expert Business Data Analyst - Now Hiring
#
#                job_location            job_via         job_schedule_type  \
# job_index
# 0             Watertown, CT    via Work Nearby                 Full-time
# 3           San Antonio, TX  via Diversity.com                 Full-time
# 5                  Anywhere   via ZipRecruiter  Contractor and Temp work
# 6              Dearborn, MI       via LinkedIn                 Full-time
# 9                  Anywhere   via ZipRecruiter                 Full-time
# ...                     ...                ...                       ...
# 785673         New York, NY    via Trabajo.org                 Full-time
# 785685     Indianapolis, IN    via Trabajo.org                 Full-time
# 785692           Dayton, OH    via Ai-Jobs.net                 Full-time
# 785703             Anywhere       via Snagajob                 Full-time
# 785705          Oakland, CA       via Snagajob                 Full-time
#
#            job_work_from_home            search_location     job_posted_date  \
# job_index
# 0                       False       Texas, United States 2023-06-16 13:44:15
# 3                       False       Texas, United States 2023-07-04 13:01:41
# 5                        True                    Georgia 2023-11-07 14:01:59
# 6                       False     Florida, United States 2023-03-27 13:18:18
# 9                        True    New York, United States 2023-04-23 13:02:57
# ...                       ...                        ...                 ...
# 785673                  False    New York, United States 2023-10-16 06:01:53
# 785685                  False    Illinois, United States 2023-07-16 06:01:27
# 785692                  False    Illinois, United States 2023-04-21 06:02:31
# 785703                   True       Texas, United States 2023-01-28 06:02:55
# 785705                  False  California, United States 2023-01-09 06:00:25
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# 3                           True                 False  United States
# 5                          False                 False  United States
# 6                          False                 False  United States
# 9                          False                 False  United States
# ...                          ...                   ...            ...
# 785673                      True                 False  United States
# 785685                      True                 False  United States
# 785692                     False                  True  United States
# 785703                      True                 False  United States
# 785705                     False                 False  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 0                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 5                 NaN              NaN              NaN
# 6                 NaN              NaN              NaN
# 9                 NaN              NaN              NaN
# ...               ...              ...              ...
# 785673            NaN              NaN              NaN
# 785685            NaN              NaN              NaN
# 785692           year         157500.0              NaN
# 785703            NaN              NaN              NaN
# 785705            NaN              NaN              NaN
#
#                             company_name  \
# job_index
# 0                   Boehringer Ingelheim
# 3           Southwest Research Institute
# 5                        smart folks inc
# 6          Miracle Software Systems, Inc
# 9             Radwell International, LLC
# ...                                  ...
# 785673              JPMorgan Chase & Co.
# 785685            Aara Technologies, Inc
# 785692                            Tenet3
# 785703       Axelon Services Corporation
# 785705                  PG&E Corporation
#
#                                                   job_skills  \
# job_index
# 0                                                        NaN
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# ...                                                      ...
# 785673                                                   NaN
# 785685                                      ['sql', 'excel']
# 785692                             ['python', 'matlab', 'r']
# 785703                                                   NaN
# 785705                          ['sql', 'python', 'tableau']
#
#                                              job_type_skills
# job_index
# 0                                                        NaN
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...
# ...                                                      ...
# 785673                                                   NaN
# 785685     {'analyst_tools': ['excel'], 'programming': ['...
# 785692            {'programming': ['python', 'matlab', 'r']}
# 785703                                                   NaN
# 785705     {'analyst_tools': ['tableau'], 'programming': ...
#
# [206292 rows x 17 columns]

# %%
median_pivot = df_usa.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc=['median','min','max'])

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
median_pivot.sort_values(by=('median','salary_year_avg'),ascending = False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0
