# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset(
    'lukebarousse/data_jobs',
    split='train'
)

# Convert to Pandas
df = dataset.to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

print("Data loaded successfully!")
print(df.shape)
# Out:
# Data loaded successfully!
# (785741, 17)

# %%
df['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %%
def projected_salary(salary):
    return salary * 1.03

df['salary_year_avg'].apply(projected_salary)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_salary = df[pd.notna(df['salary_year_avg'])].copy()

def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary) 

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary * 1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['job_skills'][5]
# Out:
# "['python', 'sql', 'gcp']"

# %%
import ast

# %%
type(ast.literal_eval(df['job_skills'][5]))
# Out:
# list

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
          return ast.literal_eval(skill_list)

df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
df['job_skills'][5]
# Out:
# ['python', 'sql', 'gcp']

# %%
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['job_skills'] = df['job_skills'].apply(lambda skill_list:ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\base.py:1022, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1019 if isinstance(arr, ExtensionArray):
#    1020     return arr.map(mapper, na_action=na_action)
# -> 1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~\anaconda3\envs\python_course\Lib\site-packages\pandas\core\algorithms.py:1715, in map_array(arr, mapper, na_action)
#    1713 values = arr.astype(object, copy=False)
#    1714 if na_action is None:
# -> 1715     return lib.map_infer(values, mapper)
#    1716 else:
#    1717     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
# -> 3071 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[30], line 1, in <lambda>(skill_list)
# ----> 1 df['job_skills'] = df['job_skills'].apply(lambda skill_list:ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
df['job_skills'][5]
# Out:
# ['python', 'sql', 'gcp']

# %%
df_salary.head(50)
# Out:
#                 job_title_short  \
# 28               Data Scientist
# 77                Data Engineer
# 92                Data Engineer
# 100              Data Scientist
# 109                Data Analyst
# 116              Data Scientist
# 146               Data Engineer
# 180                Data Analyst
# 212              Data Scientist
# 257              Data Scientist
# 307               Data Engineer
# 339               Data Engineer
# 380               Data Engineer
# 388               Data Engineer
# 410                Data Analyst
# 450              Data Scientist
# 495        Senior Data Engineer
# 520            Business Analyst
# 545               Data Engineer
# 571               Data Engineer
# 573        Senior Data Engineer
# 645            Business Analyst
# 654               Data Engineer
# 657        Senior Data Engineer
# 679           Software Engineer
# 704               Data Engineer
# 719               Data Engineer
# 726        Senior Data Engineer
# 733        Senior Data Engineer
# 762               Data Engineer
# 773               Data Engineer
# 813               Data Engineer
# 923               Data Engineer
# 982         Senior Data Analyst
# 988                Data Analyst
# 990         Senior Data Analyst
# 993               Data Engineer
# 1011       Senior Data Engineer
# 1042  Machine Learning Engineer
# 1106              Data Engineer
# 1107             Data Scientist
# 1148       Senior Data Engineer
# 1164              Data Engineer
# 1209  Machine Learning Engineer
# 1238       Senior Data Engineer
# 1257             Data Scientist
# 1261       Senior Data Engineer
# 1280          Software Engineer
# 1284              Data Engineer
# 1313              Data Engineer
#
#                                               job_title  \
# 28                                  CRM Data Specialist
# 77                                        Data Engineer
# 92              Remote - Data Engineer - Permanent - W2
# 100             Data Scientist, Risk Data Mining - USDS
# 109               Senior Supply Chain Analytics Analyst
# 116                                      Data Scientist
# 146   Data Engineer Graduate (Real Time Communicatio...
# 180                                    Data Analyst III
# 212        NATOIS-0008 Data Scientist (NS) - TUE 13 Jun
# 257   Senior Bioinformatics Research Scientist- Data...
# 307                                       Data Engineer
# 339   Global Market Leading Energy Firm - Staff Data...
# 380                             Snaplogic Data Engineer
# 388                                       Data Engineer
# 410         IT Business Lead Data Analyst - VP - Hybrid
# 450                       Data Defense Developer - USDS
# 495                     Senior Software Engineer (Data)
# 520                                    Power BI Analyst
# 545                                   ERP Data Engineer
# 571   Data Engineer ETL lnformatica API SQL Engineer...
# 573                         Senior Python Data Engineer
# 645                                     Lead BI Analyst
# 654   Lead Data Engineer (DataStage) (Need only loca...
# 657   Senior Data Engineer | Series D Video Analytic...
# 679     Tech Lead Software Engineer, TikTok Data Access
# 704                                Data Engineer, Azure
# 719                                 Azure Data Engineer
# 726                       Senior Data Engineer (Hybrid)
# 733                                Senior Data Engineer
# 762        Data Engineer, Big Data Privacy and Security
# 773                             Principal Data Engineer
# 813                                 Azure Data Engineer
# 923                                   AWS Data Engineer
# 982                                 Senior Data Analyst
# 988                               DATA ANALYST (ONSITE)
# 990                                 Senior Data Analyst
# 993                               Data Engineer Level 2
# 1011                               Senior Data Engineer
# 1042                     Head of AML Operations (m/f/d)
# 1106                                      Data Engineer
# 1107            Data Scientist, Customer AI Engineering
# 1148                               Senior Data Engineer
# 1164                                      Data Engineer
# 1209                    Computer Vision Developer (R&D)
# 1238  Senior Software (Data) Engineer - Advanced Rob...
# 1257                                     Data Scientist
# 1261              Senior Data Engineer - SQL, Snowflake
# 1280  Senior Software Engineer - Live Streaming Infr...
# 1284                                  Sr. Data Engineer
# 1313                                Staff Data Engineer
#
#                                  job_location                job_via  \
# 28    San José Province, San José, Costa Rica        via Ai-Jobs.net
# 77                              Arlington, VA           via LinkedIn
# 92                                   Anywhere           via LinkedIn
# 100                         Mountain View, CA           via LinkedIn
# 109                                  Anywhere             via Get.It
# 116                                  Anywhere           via LinkedIn
# 146                               Seattle, WA           via LinkedIn
# 180                             Dos Palos, CA  via My ArkLaMiss Jobs
# 212                         Brussels, Belgium        via Ai-Jobs.net
# 257                              Brighton, TN            via Work RN
# 307                                Austin, TX           via LinkedIn
# 339                             United States           via LinkedIn
# 380                                Durham, NC           via LinkedIn
# 388                               New Ulm, MN          via KSNT Jobs
# 410                        Atlantic Beach, FL   via ComputerJobs.com
# 450                         Mountain View, CA           via LinkedIn
# 495                         San Francisco, CA           via LinkedIn
# 520                  San Pedro Sula, Honduras        via Ai-Jobs.net
# 545                               Lansing, MI           via LinkedIn
# 571                                  Anywhere        via Robert Half
# 573                            Wilmington, DE             via Indeed
# 645                                Irvine, CA           via LinkedIn
# 654                            Cincinnati, OH           via Dice.com
# 657                           Culver City, CA           via LinkedIn
# 679                              San Jose, CA           via LinkedIn
# 704                             United States           via LinkedIn
# 719                            Scottsdale, AZ             via Indeed
# 726                            Washington, DC      via Linux Careers
# 733                               Oakland, CA           via LinkedIn
# 762                              San Jose, CA           via LinkedIn
# 773                                  Anywhere             via Indeed
# 813                             United States               via Dice
# 923                                  Anywhere           via LinkedIn
# 982                           Los Angeles, CA               via Dice
# 988                           Springfield, MA             via Indeed
# 990                       Fort Lauderdale, FL            via Ladders
# 993                              Blue Ash, OH               via Dice
# 1011                           Southfield, MI            via Ladders
# 1042                        Ballerup, Denmark        via Ai-Jobs.net
# 1106                               Dallas, TX           via LinkedIn
# 1107                               London, UK        via Ai-Jobs.net
# 1148                            San Mateo, CA           via LinkedIn
# 1164                                 Anywhere           via LinkedIn
# 1209              Bengaluru, Karnataka, India        via Ai-Jobs.net
# 1238                                 Anywhere           via LinkedIn
# 1257                          Minneapolis, MN             via Adzuna
# 1261                                 Anywhere             via Indeed
# 1280                        Mountain View, CA           via LinkedIn
# 1284                         Indianapolis, IN             via Indeed
# 1313                    Tel Aviv-Yafo, Israel        via Ai-Jobs.net
#
#              job_schedule_type  job_work_from_home            search_location  \
# 28                   Full-time               False                 Costa Rica
# 77                   Full-time               False                      Sudan
# 92                   Full-time                True    Illinois, United States
# 100                  Full-time               False  California, United States
# 109                  Full-time                True    Illinois, United States
# 116                  Full-time                True       Texas, United States
# 146                  Full-time               False  California, United States
# 180                  Full-time               False  California, United States
# 212                  Full-time               False                    Belgium
# 257                  Full-time               False                    Georgia
# 307                  Full-time               False    New York, United States
# 339                  Full-time               False  California, United States
# 380                  Full-time               False    Illinois, United States
# 388                  Full-time               False     Florida, United States
# 410                  Full-time               False                    Georgia
# 450                  Full-time               False    New York, United States
# 495                  Full-time               False    Illinois, United States
# 520                  Full-time               False                   Honduras
# 545                  Full-time               False                      Sudan
# 571                  Full-time                True  California, United States
# 573                  Full-time               False                      Sudan
# 645                  Full-time               False  California, United States
# 654                 Contractor               False                      Sudan
# 657                  Full-time               False                    Georgia
# 679                  Full-time               False    Illinois, United States
# 704   Full-time and Contractor               False    Illinois, United States
# 719                  Full-time               False  California, United States
# 726                  Full-time               False  California, United States
# 733                  Full-time               False                      Sudan
# 762                  Full-time               False                      Sudan
# 773                  Full-time                True       Texas, United States
# 813                  Full-time               False     Florida, United States
# 923                  Full-time                True  California, United States
# 982                  Full-time               False  California, United States
# 988                  Full-time               False    New York, United States
# 990                  Full-time               False     Florida, United States
# 993                  Full-time               False                      Sudan
# 1011                 Full-time               False    New York, United States
# 1042                 Full-time               False                    Denmark
# 1106                 Full-time               False     Florida, United States
# 1107                 Full-time               False             United Kingdom
# 1148                 Full-time               False                      Sudan
# 1164                 Full-time                True    Illinois, United States
# 1209                 Full-time               False                      India
# 1238                 Full-time                True                    Georgia
# 1257                 Full-time               False    Illinois, United States
# 1261                 Full-time                True     Florida, United States
# 1280                 Full-time               False  California, United States
# 1284                 Full-time               False    Illinois, United States
# 1313                 Full-time               False                     Israel
#
#          job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28   2023-08-01 13:37:57                  False                 False
# 77   2023-06-26 14:22:54                  False                 False
# 92   2023-02-21 13:29:59                  False                  True
# 100  2023-07-31 13:01:18                  False                  True
# 109  2023-10-12 13:02:19                  False                  True
# 116  2023-10-04 13:04:23                  False                 False
# 146  2023-10-21 13:06:16                  False                  True
# 180  2023-02-27 13:00:39                  False                  True
# 212  2023-06-05 13:56:28                  False                 False
# 257  2023-11-20 13:40:09                  False                 False
# 307  2023-10-03 13:05:31                  False                 False
# 339  2023-09-22 13:07:57                  False                 False
# 380  2023-08-16 13:26:21                   True                 False
# 388  2023-08-20 13:32:05                  False                 False
# 410  2023-01-10 13:59:02                  False                 False
# 450  2023-12-02 13:19:59                  False                  True
# 495  2023-06-20 13:07:37                  False                  True
# 520  2023-07-24 14:05:29                   True                 False
# 545  2023-01-04 13:58:44                  False                 False
# 571  2023-07-20 13:07:40                   True                 False
# 573  2023-09-16 13:13:50                  False                 False
# 645  2023-08-11 13:01:18                  False                 False
# 654  2023-09-22 13:38:56                   True                 False
# 657  2023-10-09 14:07:46                  False                  True
# 679  2023-12-31 13:03:14                  False                  True
# 704  2023-10-11 13:07:54                   True                 False
# 719  2023-05-15 13:22:59                   True                 False
# 726  2023-05-02 13:09:09                  False                  True
# 733  2023-07-06 13:41:35                  False                 False
# 762  2023-06-18 13:38:44                  False                  True
# 773  2023-05-17 13:22:20                   True                 False
# 813  2023-02-28 13:14:02                  False                  True
# 923  2023-08-09 13:05:40                  False                  True
# 982  2023-02-03 13:01:29                  False                 False
# 988  2023-11-21 13:00:13                  False                 False
# 990  2023-01-02 13:01:55                  False                  True
# 993  2023-07-11 14:10:29                   True                 False
# 1011 2023-08-09 13:04:52                  False                  True
# 1042 2023-06-14 13:25:40                  False                 False
# 1106 2023-04-10 13:08:31                  False                  True
# 1107 2023-06-20 13:12:50                  False                 False
# 1148 2023-05-17 14:10:56                  False                 False
# 1164 2023-10-09 13:30:25                  False                  True
# 1209 2023-02-18 13:12:30                  False                 False
# 1238 2023-03-14 13:48:49                  False                 False
# 1257 2023-02-21 13:25:40                  False                  True
# 1261 2023-05-12 13:27:56                   True                  True
# 1280 2023-07-09 13:04:23                  False                  True
# 1284 2023-06-20 13:07:12                   True                 False
# 1313 2023-09-01 13:54:54                   True                 False
#
#          job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28        Costa Rica        year     109500.00000              NaN
# 77             Sudan        year     140000.00000              NaN
# 92     United States        year     120000.00000              NaN
# 100    United States        year     228222.00000              NaN
# 109    United States        year      89000.00000              NaN
# 116    United States        year     114000.00000              NaN
# 146    United States        year     129500.00000              NaN
# 180    United States        year      90250.00000              NaN
# 212          Belgium        year     157500.00000              NaN
# 257    United States        year     103128.00000              NaN
# 307    United States        year     185000.00000              NaN
# 339    United States        year     195000.00000              NaN
# 380    United States        year      97500.00000              NaN
# 388    United States        year      89000.00000              NaN
# 410    United States        year     133285.00000              NaN
# 450    United States        year     157500.00000              NaN
# 495    United States        year     168500.00000              NaN
# 520         Honduras        year      63000.00000              NaN
# 545            Sudan        year      80000.00000              NaN
# 571    United States        year     110000.00000              NaN
# 573            Sudan        year     160000.00000              NaN
# 645    United States        year     125000.00000              NaN
# 654            Sudan        year      70000.00000              NaN
# 657    United States        year     165000.00000              NaN
# 679    United States        year     317000.00000              NaN
# 704    United States        year     100000.00000              NaN
# 719    United States        year     111228.15625              NaN
# 726    United States        year     173500.00000              NaN
# 733            Sudan        year     160000.00000              NaN
# 762            Sudan        year     171000.00000              NaN
# 773    United States        year     180000.00000              NaN
# 813    United States        year     157500.00000              NaN
# 923    United States        year     135000.00000              NaN
# 982    United States        year      85000.00000              NaN
# 988    United States        year      62623.00000              NaN
# 990    United States        year      90000.00000              NaN
# 993            Sudan        year     125000.00000              NaN
# 1011   United States        year      90000.00000              NaN
# 1042         Denmark        year     105300.00000              NaN
# 1106   United States        year     137500.00000              NaN
# 1107  United Kingdom        year     157500.00000              NaN
# 1148           Sudan        year     155000.00000              NaN
# 1164   United States        year     190000.00000              NaN
# 1209           India        year      79200.00000              NaN
# 1238   United States        year     190000.00000              NaN
# 1257   United States        year      70700.00000              NaN
# 1261   United States        year     180000.00000              NaN
# 1280   United States        year     233500.00000              NaN
# 1284   United States        year     102500.00000              NaN
# 1313          Israel        year      79200.00000              NaN
#
#                                company_name  \
# 28                                 Netskope
# 77                               Intelletec
# 92                             Apex Systems
# 100                                  TikTok
# 109         Get It Recruit - Transportation
# 116                      4 Corner Resources
# 146                               ByteDance
# 180            California Health & Wellness
# 212                               EMW, Inc.
# 257   St. Jude Children's Research Hospital
# 307                                hackajob
# 339                                   Xcede
# 380                         KTek Resourcing
# 388                      Ledgent Technology
# 410                                    Citi
# 450                                  TikTok
# 495                                hackajob
# 520                   Charger Logistics Inc
# 545                                 Venteon
# 571                             Robert Half
# 573                    Crackajack Solutions
# 645                                   KORE1
# 654                   Strategic Systems Inc
# 657                    Coda Search│Staffing
# 679                                  TikTok
# 704                        Technical Source
# 719                               TEKletics
# 726                             Capital One
# 733                        X4 Life Sciences
# 762                                  TikTok
# 773                             CyberCoders
# 813                                   Jobot
# 923                          Effectual Inc.
# 982                                   Jobot
# 988              Springfield Public Schools
# 990                        The Farmer's Dog
# 993                           Symantrix Inc
# 1011                        Sun Communities
# 1042                                   Nets
# 1106                                    WEX
# 1107                              Tractable
# 1148                             Intelletec
# 1164                             FirstParty
# 1209                            Bosch Group
# 1238                                  TEEMA
# 1257                                 Target
# 1261                            CyberCoders
# 1280                                 TikTok
# 1284                         Insight Global
# 1313                           DoubleVerify
#
#                                              job_skills  \
# 28                                    ['gdpr', 'excel']
# 77    ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                    ['sql', 'python']
# 100                   ['sql', 'r', 'python', 'express']
# 109               ['python', 'r', 'alteryx', 'tableau']
# 116   ['r', 'python', 'sql', 't-sql', 'hadoop', 'spa...
# 146   ['golang', 'scala', 'python', 'java', 'hadoop'...
# 180                             ['excel', 'powerpoint']
# 212   ['c', 'r', 'sql', 'python', 'aws', 'azure', 'h...
# 257                                   ['r', 'electron']
# 307                                    ['nosql', 'sql']
# 339                                                 NaN
# 380                                   ['sql', 'python']
# 388                       ['sql', 'python', 'power bi']
# 410   ['sql', 'word', 'excel', 'visio', 'powerpoint'...
# 450   ['go', 'python', 'java', 'mongo', 'redis', 'aw...
# 495   ['scala', 'gcp', 'azure', 'spark', 'kafka', 'h...
# 520                                        ['power bi']
# 545                                      ['sql', 'sap']
# 571   ['sql', 'java', 'python', 'azure', 'aws', 'sno...
# 573   ['python', 'sql', 'java', 'aws', 'databricks',...
# 645                        ['sql', 'python', 'tableau']
# 654                                                 NaN
# 657   ['python', 'scala', 'sql', 'aws', 'redshift', ...
# 679   ['java', 'go', 'c++', 'python', 'mongodb', 'mo...
# 704            ['sql', 'python', 'azure', 'databricks']
# 719                          ['sql', 'python', 'azure']
# 726   ['java', 'scala', 'python', 'nosql', 'sql', 's...
# 733   ['python', 'sql', 'postgresql', 'sql server', ...
# 762                                  ['spark', 'kafka']
# 773   ['sql', 'python', 'aws', 'snowflake', 'spark',...
# 813   ['t-sql', 'c#', 'python', 'sql', 'azure', 'git...
# 923   ['python', 'sql', 'java', 'scala', 'nosql', 'a...
# 982                                      ['sas', 'sas']
# 988                         ['sql', 'excel', 'tableau']
# 990                                 ['excel', 'sheets']
# 993   ['sql', 't-sql', 'azure', 'selenium', 'ansible...
# 1011  ['sql', 'python', 'c#', 'java', 'javascript', ...
# 1042                                                NaN
# 1106               ['go', 'python', 'pyspark', 'spark']
# 1107      ['python', 'numpy', 'pandas', 'scikit-learn']
# 1148                                  ['python', 'aws']
# 1164  ['sql', 'python', 'r', 'aws', 'airflow', 'matp...
# 1209  ['python', 'opencv', 'tensorflow', 'pytorch', ...
# 1238                      ['python', 'kafka', 'django']
# 1257  ['java', 'scala', 'python', 'r', 'kotlin', 'sq...
# 1261  ['sql', 'python', 'snowflake', 'redshift', 'aw...
# 1280  ['c', 'c++', 'java', 'python', 'go', 'hadoop',...
# 1284  ['sql', 'powershell', 'azure', 'snowflake', 's...
# 1313  ['python', 'scala', 'sql', 'java', 'gcp', 'dat...
#
#                                         job_type_skills  salary_year_inflated
# 28    {'analyst_tools': ['excel'], 'libraries': ['gd...                   NaN
# 77    {'analyst_tools': ['tableau'], 'cloud': ['orac...                   NaN
# 92                   {'programming': ['sql', 'python']}                   NaN
# 100   {'programming': ['sql', 'r', 'python'], 'webfr...                   NaN
# 109   {'analyst_tools': ['alteryx', 'tableau'], 'pro...                   NaN
# 116   {'analyst_tools': ['tableau'], 'libraries': ['...                   NaN
# 146   {'libraries': ['hadoop', 'spark'], 'programmin...                   NaN
# 180          {'analyst_tools': ['excel', 'powerpoint']}                   NaN
# 212   {'analyst_tools': ['tableau'], 'cloud': ['aws'...                   NaN
# 257   {'libraries': ['electron'], 'programming': ['r']}                   NaN
# 307                   {'programming': ['nosql', 'sql']}                   NaN
# 339                                                 NaN                   NaN
# 380                  {'programming': ['sql', 'python']}                   NaN
# 388   {'analyst_tools': ['power bi'], 'programming':...                   NaN
# 410   {'analyst_tools': ['word', 'excel', 'visio', '...                   NaN
# 450   {'cloud': ['aws'], 'databases': ['redis'], 'li...                   NaN
# 495   {'cloud': ['gcp', 'azure'], 'libraries': ['spa...              176925.0
# 520                     {'analyst_tools': ['power bi']}                   NaN
# 545   {'analyst_tools': ['sap'], 'programming': ['sq...                   NaN
# 571   {'cloud': ['azure', 'aws', 'snowflake'], 'prog...                   NaN
# 573   {'cloud': ['aws', 'databricks', 'redshift'], '...              168000.0
# 645   {'analyst_tools': ['tableau'], 'programming': ...                   NaN
# 654                                                 NaN                   NaN
# 657   {'cloud': ['aws', 'redshift'], 'libraries': ['...              173250.0
# 679   {'databases': ['mongodb', 'mysql', 'redis'], '...                   NaN
# 704   {'cloud': ['azure', 'databricks'], 'programmin...                   NaN
# 719   {'cloud': ['azure'], 'programming': ['sql', 'p...                   NaN
# 726   {'cloud': ['redshift', 'snowflake', 'aws', 'az...              182175.0
# 733   {'cloud': ['aws', 'snowflake'], 'databases': [...              168000.0
# 762                   {'libraries': ['spark', 'kafka']}                   NaN
# 773   {'analyst_tools': ['tableau', 'microstrategy']...                   NaN
# 813   {'cloud': ['azure'], 'other': ['github'], 'pro...                   NaN
# 923   {'cloud': ['aws', 'azure', 'redshift', 'bigque...                   NaN
# 982   {'analyst_tools': ['sas'], 'programming': ['sa...               89250.0
# 988   {'analyst_tools': ['excel', 'tableau'], 'progr...                   NaN
# 990              {'analyst_tools': ['excel', 'sheets']}               94500.0
# 993   {'cloud': ['azure'], 'libraries': ['selenium']...                   NaN
# 1011  {'cloud': ['azure', 'databricks'], 'programmin...               94500.0
# 1042                                                NaN                   NaN
# 1106  {'libraries': ['pyspark', 'spark'], 'programmi...                   NaN
# 1107  {'libraries': ['numpy', 'pandas', 'scikit-lear...                   NaN
# 1148      {'cloud': ['aws'], 'programming': ['python']}              162750.0
# 1164  {'analyst_tools': ['tableau', 'looker'], 'clou...                   NaN
# 1209  {'libraries': ['opencv', 'tensorflow', 'pytorc...                   NaN
# 1238  {'libraries': ['kafka'], 'programming': ['pyth...              199500.0
# 1257  {'libraries': ['spark'], 'programming': ['java...                   NaN
# 1261  {'cloud': ['snowflake', 'redshift', 'aws'], 'l...              189000.0
# 1280  {'libraries': ['hadoop', 'spark', 'kafka'], 'p...                   NaN
# 1284  {'cloud': ['azure', 'snowflake'], 'libraries':...                   NaN
# 1313  {'cloud': ['gcp', 'databricks', 'bigquery'], '...                   NaN

# %%
def projected_salary(row):
    if "Senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']

df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis=1)

df_salary[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
df['salary_year_inflated'] = df.apply(lambda row: 1.05 * row['salary_year_avg'] if 'Senior' in row['job_title_short'] else 1.03 * row['salary_year_avg'], axis=1)

df[pd.notna(df['salary_year_avg'])][['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]
